# %%
for i in range(3):
 for j in range(3):
  print("*",end=" ")
 print( )
# Out:
# * * *
# * * *
# * * *

# %%
for i in range(3):
 for j in range(3):
  print("*",end=" ")
 print( )
# Out:
# * * *
# * * *
# * * *

# %%
num=7
if num%2==0:
  print("irrigation day")
else:
  print("rest day")
# Out:
# rest day

# %%
def greet_farmer():
  """a simple greeting function"""
  print("welcome to samrt farming")
greet_farmer
# Out:
# <function __main__.greet_farmer()>

# %%
rainfall=float(input("enter the rainfall in mm"))
if(rainfall >600):
 print("suitable for paddy")
else:
  print("not suitable")
# Out:
# enter the rainfall in mm850.63
# suitable for paddy

# %%
for i in range(1,6):
  for j in range(1,6):
    print(i*j,end="\t")
  print()
# Out:
# 1	2	3	4	5
# 2	4	6	8	10
# 3	6	9	12	15
# 4	8	12	16	20
# 5	10	15	20	25

# %%
for i in range(1,6):
  for j in range(1,6):
    print(i/j,end="\t")
  print()
# Out:
# 1.0	0.5	0.3333333333333333	0.25	0.2
# 2.0	1.0	0.6666666666666666	0.5	0.4
# 3.0	1.5	1.0	0.75	0.6
# 4.0	2.0	1.3333333333333333	1.0	0.8
# 5.0	2.5	1.6666666666666667	1.25	1.0

# %%
for i in range(1,6):
  for j in range(1,6):
    print(i**j,end="\t")
  print()
# Out:
# 1	1	1	1	1
# 2	4	8	16	32
# 3	9	27	81	243
# 4	16	64	256	1024
# 5	25	125	625	3125

# %%
for i in range(1,6):
  for j in range(1,6):
    print(i%j,end="\t")
  print()
# Out:
# 0	1	1	1	1
# 0	0	2	2	2
# 0	1	0	3	3
# 0	0	1	0	4
# 0	1	2	1	0

# %%
for i in range(2):
  for j in range(3):
    print("i is",i,"j is",j)
  print()
# Out:
# i is 0 j is 0
# i is 0 j is 1
# i is 0 j is 2
#
# i is 1 j is 0
# i is 1 j is 1
# i is 1 j is 2

# %%
for i in range(2):
  for j in range(3):
    print("i=",i, "j =",j)
  print()
# Out:
# i= 0 j = 0
# i= 0 j = 1
# i= 0 j = 2
#
# i= 1 j = 0
# i= 1 j = 1
# i= 1 j = 2

# %%
for i in range(2):
  for j in range(3):
    print("i=",i and "j =",j)
  print()
# Out:
# i= 0 0
# i= 0 1
# i= 0 2
#
# i= j = 0
# i= j = 1
# i= j = 2

# %%
rows=int(input("enter the number of rows"))
cols=int(input("enter the number of columns"))
for i in range(rows):
  for j in range(cols):
    print("bhagavan",end=" ")
  print( )
# Out:
# enter the number of rows3
# enter the number of columns5
# bhagavan bhagavan bhagavan bhagavan bhagavan
# bhagavan bhagavan bhagavan bhagavan bhagavan
# bhagavan bhagavan bhagavan bhagavan bhagavan
